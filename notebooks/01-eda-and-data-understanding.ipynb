# %%
import os, json

os.makedirs("/root/.kaggle", exist_ok=True)
with open("/root/.kaggle/kaggle.json", "w") as f:
    json.dump({"username": "imaswath", "key": "KGAT_0cca0a5cba5cd38cd70e61d093fc4fce"}, f)
# !chmod 600 /root/.kaggle/kaggle.json

# Download competition dataset
os.system('kaggle datasets download -d wordsforthewise/lending-club --unzip')
print("Done!")
# Out:
# Done!

# %%
for f.

# %%
import pandas as pd

train_labels = pd.read_csv('/kaggle/input/competitions/amex-default-prediction/train_labels.csv')

print(train_labels.shape) #shape of the data frame
print(train_labels.head()) # top 5 records from the DF
print(train_labels['target'].value_counts()) #number of records with the two values of "target" column
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_517/1942822378.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 train_labels = pd.read_csv('/kaggle/input/competitions/amex-default-prediction/train_labels.csv')
#       4
#       5 print(train_labels.shape) #shape of the data frame
#
# ...

# %%
train_data = pd.read_csv("/kaggle/input/competitions/amex-default-prediction/train_data.csv",nrows= 100)
print(train_data.shape)
print(train_data.head())
print(train_data.dtypes)
# Out:
# (100, 190)
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709  ...
# 1  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714  ...
# 2  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423  ...
# 3  0.002455  0.013683  1.002700  0.001373  0.117169  0.000685  0.005531  ...
# 4  0.002483  0.015193  1.000727  0.007605  0.117325  0.004653  0.009312  ...
#
# ...

# %%
print("Unique customers count:",train_data['customer_ID'].nunique())
# Out:
# Unique customers count: 8

# %%
print("Rows per customer:",train_data['customer_ID'].value_counts().describe())
# Out:
# Rows per customer: count     8.000000
# mean     12.500000
# std       1.414214
# min       9.000000
# 25%      13.000000
# 50%      13.000000
# 75%      13.000000
# max      13.000000
# Name: count, dtype: float64

# %%
print('Unique statement dates:', train_data['S_2'].unique())
# Out:
# Unique statement dates: ['2017-03-09' '2017-04-07' '2017-05-28' '2017-06-13' '2017-07-16'
#  '2017-08-04' '2017-09-18' '2017-10-08' '2017-11-20' '2017-12-04'
#  '2018-01-11' '2018-02-21' '2018-03-13' '2017-03-01' '2017-04-16'
#  '2017-05-07' '2017-06-25' '2017-07-30' '2017-08-19' '2017-09-15'
#  '2017-10-20' '2017-11-24' '2017-12-29' '2018-01-26' '2018-02-06'
#  '2018-03-25' '2017-03-11' '2017-04-11' '2017-05-12' '2017-06-10'
#  '2017-07-12' '2017-08-12' '2017-09-11' '2017-10-12' '2017-11-11'
#  '2017-12-12' '2018-01-12' '2018-02-09' '2018-03-12' '2017-03-31'
#  '2017-04-21' '2017-05-29' '2017-06-24' '2017-08-06' '2017-10-23'
#  '2017-11-25' '2018-01-18' '2018-02-03' '2018-03-29' '2017-03-30'
#  '2017-04-22' '2017-05-30' '2017-06-22' '2017-07-22' '2017-08-07'
#  '2017-09-22' '2017-10-29' '2017-11-29' '2017-12-30' '2018-01-30'
#  '2018-02-27' '2018-03-30' '2017-03-19' '2017-04-28' '2017-05-19'
#  '2017-09-21' '2017-10-26' '2017-11-08' '2018-02-11' '2018-03-19'
# ...

# %%
# Check full file size before loading everything
import os

path = '/kaggle/input/competitions/amex-default-prediction/'

for f in os.listdir(path):
    size = os.path.getsize(path + f) / (1024**3)  # convert to GB
    print(f"{f}: {size:.2f} GB")
# Out:
# sample_submission.csv: 0.06 GB
# train_data.csv: 15.27 GB
# test_data.csv: 31.50 GB
# train_labels.csv: 0.03 GB

# %%
# ordering and dtype optimisation for cols
float_cols = [f'D_{i}' for i in range (1,30)] +\
[f'S_{i}' for i in range (1,22)] +\
[f'P_{i}' for i in range (1,45)] +\
[f'B_{i}' for i in range (1,45)] +\
[f'R_{i}' for i in range (1,30)]

dtypes = {col: 'float32' for col in float_cols}

# %%
# !git clone https://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@github.com/imaswath/loan-default-prediction.git
# Out:
# fatal: destination path 'loan-default-prediction' already exists and is not an empty directory.
